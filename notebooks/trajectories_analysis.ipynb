# %% [markdown]
# # Trajectories Analysis

# %%
import sys
sys.path.append('C:/Users/nikol/Documents/GitHub/EnsembleTools')

# %%
from dpet.ensemble_analysis import EnsembleAnalysis
ens_codes = [
    "PED00423e001",
    "PED00424e001",
]
data_dir = 'C:/Users/nikol/Documents/test_dir'

analysis = EnsembleAnalysis(ens_codes, data_dir)
analysis.download_from_ped()
analysis.generate_trajectories()
# Out:
# Downloading entry PED00423e001 from PED.
# File already exists. Skipping download.
# File already exists. Skipping extracting.
# Downloading entry PED00424e001 from PED.
# File already exists. Skipping download.
# File already exists. Skipping extracting.
# Trajectory already exists for ensemble PED00423e001. Loading trajectory.
# Trajectory already exists for ensemble PED00424e001. Loading trajectory.

# %%
analysis.trajectories_plot_total_sasa()

# %%
analysis.plot_rg_vs_asphericity()
# Out:
# Pearson coeff for PED00423e001 = 0.767
# Pearson coeff for PED00424e001 = 0.767

# %%
analysis.trajectories_plot_density()

# %%
analysis.plot_rg_vs_prolateness()
# Out:
# Pearson coeff for PED00423e001 = -0.403
# Pearson coeff for PED00424e001 = -0.415

# %%
analysis.trajectories_plot_prolateness()

# %%
analysis.trajectories_plot_dihedrals()

# %%
analysis.plot_relative_helix_content()

# %%
analysis.trajectories_plot_rg_comparison()

# %%
analysis.plot_average_dmap_comparison()

# %%
analysis.plot_cmap_comparison(title="contact")

# %%
analysis.plot_distance_distribution_multiple()
