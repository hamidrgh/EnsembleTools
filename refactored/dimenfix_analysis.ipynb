# %% [markdown]
# # DimenFix Analysis

# %%
from ensemble_analysis import EnsembleAnalysis
from ped_entry import PedEntry

# %%
ped_entries = [
    PedEntry('PED00423', ['e001']),
    PedEntry('PED00424', ['e001']),
]
data_dir = 'C:/Users/nikol/Documents/test_dir'
featurization = "phi_psi"
reduce_dim_method = "dimenfix"

featurization_params = {'featurization': featurization}
reduce_dim_params = {'method': reduce_dim_method}
cluster_params = {'range_n_clusters':[2, 3, 4, 5, 6]}

# %%
analysis = EnsembleAnalysis(ped_entries, data_dir)
analysis.execute_pipeline(featurization_params, reduce_dim_params, cluster_params)
# Out:
# File already exists. Skipping download.
# File already exists. Skipping extracting.
# File already exists. Skipping download.
# File already exists. Skipping extracting.
# Trajectory already exists. Loading trajectory.
# Trajectory already exists. Loading trajectory.
# Performing feature extraction for PED ID: PED00423, ensemble ID: e001.
# Transformed ensemble shape: (1000, 182)
# Performing feature extraction for PED ID: PED00424, ensemble ID: e001.
# Transformed ensemble shape: (1000, 182)
# ...

# %%
analysis.dimenfix_scatter_plot()

# %%
analysis.dimenfix_scatter_plot_2()

# %%
analysis.dimenfix_cluster_scatter_plot()
# Out:
# c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.

# %%
analysis.dimenfix_cluster_scatter_plot_2()
