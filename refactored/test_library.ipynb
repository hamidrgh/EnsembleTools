# %%
from ensemble_analysis import EnsembleAnalysis
from ped_entry import PedEntry

# %%
ped_entries = [
    PedEntry('PED00423', ['e001']),
    PedEntry('PED00424', ['e001']),
]
data_dir = 'C:/Users/nikol/Documents/test_dir'
reduce_dim_method = "tsne"
perplexityVals = range(500,1001,500)
dim_reduction_dir = 'C:/Users/nikol/Documents/test_dir/dim_reduction'

analysis = EnsembleAnalysis(ped_entries, data_dir)
analysis.download_from_ped()
# Out:
# File already exists. Skipping download.
# File already exists. Skipping extracting.
# File already exists. Skipping download.
# File already exists. Skipping extracting.

# %%
analysis.generate_trajectories()
# Out:
# Trajectory already exists. Loading trajectory.
# Trajectory already exists. Loading trajectory.

# %%
#analysis.perform_feature_extraction(featurization='ca_dist', seq_sep=2, inverse=False, normalize=True)
analysis.perform_feature_extraction(featurization='phi_psi')
# Out:
# Performing feature extraction for PED ID: PED00423, ensemble ID: e001.
# Transformed ensemble shape: (1000, 182)
# Performing feature extraction for PED ID: PED00424, ensemble ID: e001.
# Transformed ensemble shape: (1000, 182)
# ...

# %%
rg = analysis.rg_calculator()
len(rg)
# Out:
# 2000

# %%
analysis.fit_dimensionality_reduction(method=reduce_dim_method, perplexityVals = perplexityVals, metric='euclidean', dir=dim_reduction_dir)
# Out:
# tsne is running...
# c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# tsne file for the perplexity value of 500 is saved in <built-in function dir>
# tsne file for the perplexity value of 1000 is saved in <built-in function dir>
# tsne is done! All files saved in C:/Users/nikol/Documents/test_dir/dim_reduction

# %%
analysis.create_tsne_clusters(perplexityVals=perplexityVals, range_n_clusters=range(2,10,1),tsne_dir=dim_reduction_dir)
# Out:
# c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(
# c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(
# c:\Users\nikol\anaconda3\envs\tensorflowgpu\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(
# ...

# %%
analysis.tsne_ramachandran_plot(tsne_dir=dim_reduction_dir)
# Out:
# [1000.0, 2.0]
# [   0    3    4    5    6    7    8    9   10   11   13   16   17   18
#    19   20   21   22   23   24   26   27   30   33   34   36   37   40
#    41   43   44   45   47   48   49   50   51   53   56   59   60   61
#    62   64   65   68   69   70   71   72   73   75   77   78   80   81
#    83   84   85   86   87   88   89   90   91   93   94   95   97   98
#    99  102  103  105  106  107  108  109  110  112  113  114  115  116
#   117  118  119  120  121  122  123  124  125  128  130  132  135  136
#   137  138  139  140  141  142  144  145  146  149  151  152  153  154
#   155  156  157  158  159  160  161  165  167  168  169  170  171  172
#   173  174  175  177  178  179  180  181  183  186  187  188  189  190
#   192  193  194  195  196  197  199  200  201  202  203  204  205  206
#   207  208  209  210  211  213  214  216  217  220  221  222  223  224
#   225  226  227  230  231  232  233  234  235  236  237  240  241  242
# ...

# %%
analysis.tsne_ramachandran_plot_density(tsne_dir=dim_reduction_dir)
# Out:
# [1000.0, 2.0]
# [   0    3    4    5    6    7    8    9   10   11   13   16   17   18
#    19   20   21   22   23   24   26   27   30   33   34   36   37   40
#    41   43   44   45   47   48   49   50   51   53   56   59   60   61
#    62   64   65   68   69   70   71   72   73   75   77   78   80   81
#    83   84   85   86   87   88   89   90   91   93   94   95   97   98
#    99  102  103  105  106  107  108  109  110  112  113  114  115  116
#   117  118  119  120  121  122  123  124  125  128  130  132  135  136
#   137  138  139  140  141  142  144  145  146  149  151  152  153  154
#   155  156  157  158  159  160  161  165  167  168  169  170  171  172
#   173  174  175  177  178  179  180  181  183  186  187  188  189  190
#   192  193  194  195  196  197  199  200  201  202  203  204  206  207
#   208  209  210  211  213  214  216  217  220  221  222  223  224  225
#   226  227  230  231  232  233  234  235  236  237  240  241  242  244
# ...

# %%
analysis.tsne_scatter_plot(tsne_dir=dim_reduction_dir)
# Out:
# 1000.0 2.0
