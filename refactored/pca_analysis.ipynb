# %% [markdown]
# # PCA Analysis

# %% [markdown]
# ## Load data from Atlas

# %%
from ensemble_analysis import EnsembleAnalysis

ens_codes = [
    '3a1g_B'
]
data_dir = 'C:/Users/nikol/Documents/test_dir/atlas'

analysis = EnsembleAnalysis(ens_codes, data_dir)
analysis.download_from_database(database='atlas')
analysis.generate_trajectories()
# Out:
# Downloading entry 3a1g_B from Atlas.
# Download complete. Saved to: C:\Users\nikol\Documents\test_dir\atlas\3a1g_B.zip
# Downloaded file 3a1g_B.zip from Atlas.
# Extracted directory C:\Users\nikol\Documents\test_dir\atlas.
# Copied and renamed C:\Users\nikol\Documents\test_dir\atlas\3a1g_B.pdb to C:\Users\nikol\Documents\test_dir\atlas\3a1g_B_prod_R1_fit.top.pdb.
# Copied and renamed C:\Users\nikol\Documents\test_dir\atlas\3a1g_B.pdb to C:\Users\nikol\Documents\test_dir\atlas\3a1g_B_prod_R2_fit.top.pdb.
# Copied and renamed C:\Users\nikol\Documents\test_dir\atlas\3a1g_B.pdb to C:\Users\nikol\Documents\test_dir\atlas\3a1g_B_prod_R3_fit.top.pdb.
# Trajectory already exists for ensemble 3a1g_B_prod_R1_fit. Loading trajectory.
# Trajectory already exists for ensemble 3a1g_B_prod_R2_fit. Loading trajectory.
# Trajectory already exists for ensemble 3a1g_B_prod_R3_fit. Loading trajectory.

# %%
analysis.plot_average_dmap_comparison()

# %% [markdown]
# ## Featurization

# %%
analysis.perform_feature_extraction(featurization='ca_dist', seq_sep=2, normalize=False)
# Out:
# Performing feature extraction for Ensemble: 3a1g_B_prod_R1_fit.
# Transformed ensemble shape: (10001, 741)
# Performing feature extraction for Ensemble: 3a1g_B_prod_R2_fit.
# Transformed ensemble shape: (10001, 741)
# Performing feature extraction for Ensemble: 3a1g_B_prod_R3_fit.
# Transformed ensemble shape: (10001, 741)
# Feature names: ['GLY1-SER3', 'GLY1-MET4', 'GLY1-GLU5', 'GLY1-ARG6', 'GLY1-ILE7', 'GLY1-LYS8', 'GLY1-GLU9', 'GLY1-LEU10', 'GLY1-ARG11', 'GLY1-ASN12', 'GLY1-LEU13', 'GLY1-MET14', 'GLY1-SER15', 'GLY1-GLN16', 'GLY1-SER17', 'GLY1-ARG18', 'GLY1-THR19', 'GLY1-ARG20', 'GLY1-GLU21', 'GLY1-ILE22', 'GLY1-LEU23', 'GLY1-THR24', 'GLY1-LYS25', 'GLY1-THR26', 'GLY1-THR27', 'GLY1-VAL28', 'GLY1-ASP29', 'GLY1-HIS30', 'GLY1-MET31', 'GLY1-ALA32', 'GLY1-ILE33', 'GLY1-ILE34', 'GLY1-LYS35', 'GLY1-LYS36', 'GLY1-TYR37', 'GLY1-THR38', 'GLY1-SER39', 'GLY1-GLY40', 'GLY2-MET4', 'GLY2-GLU5', 'GLY2-ARG6', 'GLY2-ILE7', 'GLY2-LYS8', 'GLY2-GLU9', 'GLY2-LEU10', 'GLY2-ARG11', 'GLY2-ASN12', 'GLY2-LEU13', 'GLY2-MET14', 'GLY2-SER15', 'GLY2-GLN16', 'GLY2-SER17', 'GLY2-ARG18', 'GLY2-THR19', 'GLY2-ARG20', 'GLY2-GLU21', 'GLY2-ILE22', 'GLY2-LEU23', 'GLY2-THR24', 'GLY2-LYS25', 'GLY2-THR26', 'GLY2-THR27', 'GLY2-VAL28', 'GLY2-ASP29', 'GLY2-HIS30', 'GLY2-MET31', 'GLY2-ALA32', 'GLY2-ILE33', 'GLY2-ILE34', 'GLY2-LYS35', 'GLY2-LYS36', 'GLY2-TYR37', 'GLY2-THR38', 'GLY2-SER39', 'GLY2-GLY40', 'SER3-GLU5', 'SER3-ARG6', 'SER3-ILE7', 'SER3-LYS8', 'SER3-GLU9', 'SER3-LEU10', 'SER3-ARG11', 'SER3-ASN12', 'SER3-LEU13', 'SER3-MET14', 'SER3-SER15', 'SER3-GLN16', 'SER3-SER17', 'SER3-ARG18', 'SER3-THR19', 'SER3-ARG20', 'SER3-GLU21', 'SER3-ILE22', 'SER3-LEU23', 'SER3-THR24', 'SER3-LYS25', 'SER3-THR26', 'SER3-THR27', 'SER3-VAL28', 'SER3-ASP29', 'SER3-HIS30', 'SER3-MET31', 'SER3-ALA32', 'SER3-ILE33', 'SER3-ILE34', 'SER3-LYS35', 'SER3-LYS36', 'SER3-TYR37', 'SER3-THR38', 'SER3-SER39', 'SER3-GLY40', 'MET4-ARG6', 'MET4-ILE7', 'MET4-LYS8', 'MET4-GLU9', 'MET4-LEU10', 'MET4-ARG11', 'MET4-ASN12', 'MET4-LEU13', 'MET4-MET14', 'MET4-SER15', 'MET4-GLN16', 'MET4-SER17', 'MET4-ARG18', 'MET4-THR19', 'MET4-ARG20', 'MET4-GLU21', 'MET4-ILE22', 'MET4-LEU23', 'MET4-THR24', 'MET4-LYS25', 'MET4-THR26', 'MET4-THR27', 'MET4-VAL28', 'MET4-ASP29', 'MET4-HIS30', 'MET4-MET31', 'MET4-ALA32', 'MET4-ILE33', 'MET4-ILE34', 'MET4-LYS35', 'MET4-LYS36', 'MET4-TYR37', 'MET4-THR38', 'MET4-SER39', 'MET4-GLY40', 'GLU5-ILE7', 'GLU5-LYS8', 'GLU5-GLU9', 'GLU5-LEU10', 'GLU5-ARG11', 'GLU5-ASN12', 'GLU5-LEU13', 'GLU5-MET14', 'GLU5-SER15', 'GLU5-GLN16', 'GLU5-SER17', 'GLU5-ARG18', 'GLU5-THR19', 'GLU5-ARG20', 'GLU5-GLU21', 'GLU5-ILE22', 'GLU5-LEU23', 'GLU5-THR24', 'GLU5-LYS25', 'GLU5-THR26', 'GLU5-THR27', 'GLU5-VAL28', 'GLU5-ASP29', 'GLU5-HIS30', 'GLU5-MET31', 'GLU5-ALA32', 'GLU5-ILE33', 'GLU5-ILE34', 'GLU5-LYS35', 'GLU5-LYS36', 'GLU5-TYR37', 'GLU5-THR38', 'GLU5-SER39', 'GLU5-GLY40', 'ARG6-LYS8', 'ARG6-GLU9', 'ARG6-LEU10', 'ARG6-ARG11', 'ARG6-ASN12', 'ARG6-LEU13', 'ARG6-MET14', 'ARG6-SER15', 'ARG6-GLN16', 'ARG6-SER17', 'ARG6-ARG18', 'ARG6-THR19', 'ARG6-ARG20', 'ARG6-GLU21', 'ARG6-ILE22', 'ARG6-LEU23', 'ARG6-THR24', 'ARG6-LYS25', 'ARG6-THR26', 'ARG6-THR27', 'ARG6-VAL28', 'ARG6-ASP29', 'ARG6-HIS30', 'ARG6-MET31', 'ARG6-ALA32', 'ARG6-ILE33', 'ARG6-ILE34', 'ARG6-LYS35', 'ARG6-LYS36', 'ARG6-TYR37', 'ARG6-THR38', 'ARG6-SER39', 'ARG6-GLY40', 'ILE7-GLU9', 'ILE7-LEU10', 'ILE7-ARG11', 'ILE7-ASN12', 'ILE7-LEU13', 'ILE7-MET14', 'ILE7-SER15', 'ILE7-GLN16', 'ILE7-SER17', 'ILE7-ARG18', 'ILE7-THR19', 'ILE7-ARG20', 'ILE7-GLU21', 'ILE7-ILE22', 'ILE7-LEU23', 'ILE7-THR24', 'ILE7-LYS25', 'ILE7-THR26', 'ILE7-THR27', 'ILE7-VAL28', 'ILE7-ASP29', 'ILE7-HIS30', 'ILE7-MET31', 'ILE7-ALA32', 'ILE7-ILE33', 'ILE7-ILE34', 'ILE7-LYS35', 'ILE7-LYS36', 'ILE7-TYR37', 'ILE7-THR38', 'ILE7-SER39', 'ILE7-GLY40', 'LYS8-LEU10', 'LYS8-ARG11', 'LYS8-ASN12', 'LYS8-LEU13', 'LYS8-MET14', 'LYS8-SER15', 'LYS8-GLN16', 'LYS8-SER17', 'LYS8-ARG18', 'LYS8-THR19', 'LYS8-ARG20', 'LYS8-GLU21', 'LYS8-ILE22', 'LYS8-LEU23', 'LYS8-THR24', 'LYS8-LYS25', 'LYS8-THR26', 'LYS8-THR27', 'LYS8-VAL28', 'LYS8-ASP29', 'LYS8-HIS30', 'LYS8-MET31', 'LYS8-ALA32', 'LYS8-ILE33', 'LYS8-ILE34', 'LYS8-LYS35', 'LYS8-LYS36', 'LYS8-TYR37', 'LYS8-THR38', 'LYS8-SER39', 'LYS8-GLY40', 'GLU9-ARG11', 'GLU9-ASN12', 'GLU9-LEU13', 'GLU9-MET14', 'GLU9-SER15', 'GLU9-GLN16', 'GLU9-SER17', 'GLU9-ARG18', 'GLU9-THR19', 'GLU9-ARG20', 'GLU9-GL ...
# Concatenated featurized ensemble shape: (30003, 741)

# %% [markdown]
# ## Dimensionality Reduction

# %%
analysis.fit_dimensionality_reduction(method='pca')
# Out:
# Reduced dimensionality ensemble shape: (10001, 10)
# Reduced dimensionality ensemble shape: (10001, 10)
# Reduced dimensionality ensemble shape: (10001, 10)

# %% [markdown]
# ## Analysis

# %%
analysis.pca_cumulative_explained_variance()
# Out:
# - Percentage of variance explained by each of the selected components:
# - First three: 68.23853254318237

# %% [markdown]
# ### Plot 2D Landscapes

# %%
analysis.pca_plot_2d_landscapes()

# %% [markdown]
# ### 1D Histograms

# %%
analysis.pca_plot_1d_histograms()

# %% [markdown]
# ### Is PC 1 from Ca-Ca correlated with Rg? For fully intrinsically disordered proteins, this is what happens.

# %% [markdown]
# An hallmark of fully-disordered ensembles at a global level is the following: when you do PCA with Ca-Ca distances, typically PC dimension 1 is strongly correlated with Rg, it describes changes in chain compactness. This is what happens in Sic1 ensembles too.

# %%
analysis.pca_rg_correlation()

# %%
num_residues = 40# Number of residues in the protein.
sel_dims = [0, 1, 2]  # Dimensionality reduction feature we want to analyze
analysis.pca_correlation_plot(num_residues=num_residues, sel_dims=sel_dims)
